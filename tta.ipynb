# %%
import torch
import albumentations
from torchvision.models import resnet18
import torchvision
import PIL
import numpy as np
import matplotlib.pyplot as plt

# %%
image = PIL.Image.open('/media/lex/ee2d4e17-32c9-4a5a-98b9-655706039d25/lexibender/data/sun397/images/128_size/b/bakery/shop/sun_abfwxkenfowtsskg.jpg')

# %%
plt.imshow(image)
